# %%
import sys
# !{sys.executable} -m pip install opencv-python matplotlib
# Out:
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# ...

# %% [markdown]
# # Filtering the image concept(Pexic)

# %%
# import numpy as np
# import cv2                         # using to upload pic in
# import matplotlib.pyplot as plt    # using to show pic

# # load the real inmage
# img_bgr = cv2.imread('photo1.jpg')     

# # change BRG to RGB color standard
# img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# def axis0():
#     return img.sum(axis=0)   # axis=0 calculate form the top of the row to down
    
# def axis1():
#     return img.sum(axis=1)   # for axis=1 mean that "Calculate across the columns"n

# def axis2():
#     return img.sum(axis=2)    # it is control on the "color"

# # this is the part that we checking color on the size on the pic

# # Axis 0=:50,  Axis 1=:100,  Axis 2=0
# red_top = img[:50,:100,0]            # this is what i slicing on the top of the picture and it is red cuz i use index of axis=2
# green_mid = img[33:66, 66:132, 1]    # this is in the middle i use asix=2
# black_end = img[66:,133:, 2]         # using axis=2

# # we combind it together red and green
# red_and_green = img[:30,:30,0:2]

# # > 200 it mean we fill only use to fill only the pixce that have green color by using axis=2 is mean green
# mask = img[:,:,1] > 200   

# # this we using to filter the green color in axis=2 by using index=1 to checking


# # uisng to add one more layer to control on the RGB 
# mask_3d = mask[:, :, np.newaxis]


# # -> change grren to black part

# # in numpy we use an if..else condition like this 
#                   # checking on the green is largest > 100 & green > red & green > Blue
# mask_green = (img[:, :, 1] > 100) & (img[:, :, 1] > img[:, :, 0]) & (img[:, :, 1] > img[:, :, 2])  
# filtered_img = img.copy()                # copy img to make sure that your pic is self when modify 
# filtered_img[mask_green] = [0, 0, 0]     # after we filtering the green out we put the Black color in by uisng this 


# # using to filtering white out and put yellow in it 
# mask_white = (img[:, :, 0] > 200) & (img[:, :, 1] > 200) & (img[:, :, 2] > 200)
# final_img = img.copy()
# final_img[mask_white] = [255, 255, 0]


# plt.figure(figsize=(12, 4))
# plt.subplot(1, 3, 1)
# plt.title("1. Original Image")
# plt.imshow(img)  # calling the real one        
# plt.axis()       # if u do not wnat to put an axis u can using ('off')
  
# plt.subplot(1, 3, 2)
# plt.title("2. Green to Black")
# plt.imshow(filtered_img)     # call the filter that we have filtering already 
# plt.axis()    

# plt.subplot(1, 3, 3)
# plt.title("3. change background") 
# plt.imshow(final_img)        # change background
# plt.axis()

# plt.figure(figsize=(15, 5))

# plt.show()

# %% [markdown]
# # Testing

# %%
# import numpy as np
# import cv2                         # using to upload pic in
# import matplotlib.pyplot as plt    # using to show pic

# # load the real inmage
# img_bgr = cv2.imread('photo1.jpg')     

# # change BRG to RGB color standard
# img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# def axis0():
#     return img.sum(axis=0)   # axis=0 calculate form the top of the row to down
    
# def axis1():
#     return img.sum(axis=1)   # for axis=1 mean that "Calculate across the columns"n

# def axis2():
#     return img.sum(axis=2)    # it is control on the "color"

# red_top = img[:50,:100,0]           
# green_mid = img[33:66, 66:132, 1]   
# black_end = img[66:,133:, 2]      
# red_and_green = img[:30,:30,0:2]
# mask = img[:,:,1] > 200   

# brighter_img = cv2.add(img, 50)
# gamma = 2.0 
# gamma_corrected = np.power(img / 255.0, gamma) * 255.0

# final_gamma = np.clip(gamma_corrected, 0, 255).astype(np.uint8)
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 3, 1); plt.imshow(img); plt.title("Original")
# plt.subplot(1, 3, 2); plt.imshow(brighter_img); plt.title("Linear Brightening")
# plt.subplot(1, 3, 3); plt.imshow(final_gamma); plt.title(f"Gamma {gamma}")
# plt.figure(figsize=(15, 5))

# plt.show()
