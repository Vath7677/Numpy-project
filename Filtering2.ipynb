# %%
# # creating arrays & attributes 
# import numpy as np
# import matplotlib.pyplot as plt

# img_array = plt.imread('photo1.jpg')
# # blank_canvas = np.zeros(shape=(4733, 4171, 3), dtype='uint8')

# img_red_only = img_array.copy()
# # 0 red, 1 green, 2 blue
# img_red_only[:, :, 0]=0
# img_red_only[:, :, 2]=0

# print(img_red_only)
# print(img_array)
# # print(blank_canvas)
# # print(img_array.shape)
# # print(img_array.ndim)
# # print(img_array.size)
# # print(img_array.dtype)
# print(f"Min value of the image array is: {np.min(img_array)}")
# print(f"Max value of the image array is: {np.max(img_array)}")
# print(f"Average value of the image array is: {np.mean(img_array)}")

# plt.imshow(result_img)
# plt.imshow(img_red_only)
# plt.imshow(img_array)
# # plt.imshow(blank_canvas)
# # plt.axis('off')

# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # 1. Create a random color image (e.g., 100x100 pixels)
# # Using 'uint8' for standard 0-255 color values
# random_img = np.random.randint(0, 256, (100, 100, 3), dtype='uint8')

# # 2. Calculate "Brightness" (Luminance)
# # We sum the RGB channels or use a weighted average
# # Greyscale = 0.299*R + 0.587*G + 0.114*B (Standard formula)
# brightness = np.mean(random_img, axis=2) 

# # 3. Find the coordinates of the Lightest and Darkest spots
# darkest_idx = np.unravel_index(np.argmin(brightness), brightness.shape)
# lightest_idx = np.unravel_index(np.argmax(brightness), brightness.shape)

# # 4. Visualization
# fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# # Show the random image
# ax[0].imshow(random_img)
# ax[0].set_title('Random Color Image')

# # Mark the spots on the brightness map
# ax[1].imshow(brightness, cmap='gray')
# ax[1].scatter(darkest_idx[1], darkest_idx[0], color='red', s=100, label='Darkest', marker='x')
# ax[1].scatter(lightest_idx[1], lightest_idx[0], color='cyan', s=100, label='Lightest', marker='o')
# ax[1].set_title('Brightness Map (Heatmap)')
# ax[1].legend()

# plt.show()

# print(f"Darkest pixel location (y, x): {darkest_idx}")
# print(f"Lightest pixel location (y, x): {lightest_idx}")
# Out:
# Darkest pixel location (y, x): (np.int64(21), np.int64(91))
# Lightest pixel location (y, x): (np.int64(56), np.int64(14))
