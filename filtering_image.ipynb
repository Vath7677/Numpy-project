# %%
import numpy as np
import matplotlib.pyplot as plt

img_array = plt.imread('photo1.jpg')

x = img_array.copy()

x[:,:,0] = 0
x[:,:,2] = 0
# print(x.size)

green_only = x[:, :, 1] > 150

# print(x[green_only])
print(f"Count index: {len(x[green_only])}")

y = np.random.randint(0,256,size=(len(x[green_only])), dtype='uint8')

# print(len(y))
# print(y)
# print(x)
# print(f"Modified {len(x[green_only])} pixels.")


x[green_only, 1] = y

slide = x[:100,:200]

plt.imshow(slide)
plt.show()



# img_read_only = img_array.copy()
# img_read_only[:,:,1] = 0
# img_read_only[:,:,2] = 0

# img_read_green = img_array.copy()
# img_read_green[:,:,0] = 0
# img_read_green[:,:,2] = 0
 
# -> this part is use to show a number that we can know that what picxe that they use

# print(img_array)
# print(img_read_only)
# print(img_array.shape)
# print(img_array.ndim)
# print(img_array.size)
# print(img_array.dtype)

# print(f"Min of value: {np.min(img_read_only)}")
# print(f"Max of value: {np.max(img_read_only)}")
# mean_red_only = np.mean(img_array[:,:,0])
# mean_green_only = np.mean(img_array[:,:,1])
# mean_blue_only = np.mean(img_array[:,:,2])

# print(mean_red_only)
# print(mean_green_only)
# print(mean_blue_only)
# print(img_array)
# print(f"Average of value: {np.average(img_read_only)}")

# blank_canvas = np.zeros(shape=(3148, 4561, 3))

# "set the side that we see on the sreen"
# plt.figure(figsize=(20, 10))

# plt.subplot(2, 3, 1)
# plt.title("Zin") 
# plt.imshow(img_array)
# # plt.axis()

# plt.subplot(2, 3, 2)
# plt.title("Black_canvas") 
# plt.imshow(blank_canvas)
# # plt.axis()

# plt.subplot(2, 3, 3)
# plt.title("Read only red") 
# plt.imshow(img_read_only)
# # plt.axis()

# plt.subplot(2, 3, 4)
# plt.title("Read only green") 
# plt.imshow(img_read_green)
# # plt.axis()
# Out:
# Count index: 4027102
